# %% [markdown]
# # Comparing Timeseries of Transport files from Observational Data
# *Akira Di Sandro, 6/25/20*
# <br>
# In this notebook, I will be plotting time series of transport from different files on the same figure to compare them and make observations.

# %% [markdown]
# ## 1.  Import packages and Load in data

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import random

# %%
from scipy.io import loadmat
x = loadmat('allTransport_SolomonStrait.mat')

# %% [markdown]
# ## 2. Convert time stamps into legible and usable ones

# %% [markdown]
# ### a. Legible to humans

# %%
datenums = x['time'][0]
# this line below reads matlab datenums and returns datetime in human legible format
timestamps = pd.to_datetime(datenums-719529, unit='D')

# %% [markdown]
# ### b. Timestamps in vector format for python

# %%
# this code reads matlab datenums and returns it in a datetime vector. 
def matlab2datetime(matlab_datenum):
    day = dt.datetime.fromordinal(int(matlab_datenum))
    dayfrac = dt.timedelta(days=matlab_datenum%1) - dt.timedelta(days = 366)
    return day + dayfrac

# %%
py_dt = []

for time in datenums:
    py_dt = np.concatenate([py_dt, [matlab2datetime(int(time))]])
#py_dt

# %% [markdown]
# ## 3. Plot Transport timeseries

# %% [markdown]
# I need the 'string find' code here to find files that I'm interested in.

# %%
x['T'][0]
# Out:
# array([ 12.8910476 ,   8.80225101,   3.24539391,  -2.51741866,
#         -7.85933446, -12.48677851, -16.00495215, -17.99676509,
#        -18.4706279 , -18.00986233, -17.35210306, -16.84211049,
#        -16.33865188, -15.60638693, -14.68125309, -13.79138161,
#        -12.97432743, -11.90417989, -10.16364956,  -7.70976456,
#         -5.06270383,  -3.03513291,  -2.26565998,  -2.98574434,
#         -5.11145289,  -8.39842812, -12.40992859, -16.45445198,
#        -19.80966791, -22.15875873, -23.74659283, -24.99412663,
#        -25.95909216, -26.27086399, -25.60037046, -24.0757151 ,
#        -22.18234133, -20.34154546, -18.68831153, -17.20058673,
#        -15.86858415, -14.64800117, -13.33955494, -11.65308579,
#         -9.43472189,  -6.80990702,  -4.11391456,  -1.71882853,
#          0.09000795,   1.17401156,   1.60324141,   1.68330348,
#          1.83458913,   2.32954178,   3.09076977,   3.77221265,
#          4.09197891,   4.10422129,   4.09943887,   4.20780033,
#          4.1265712 ,   3.30906612,   1.47450127,  -1.07237303,
#         -3.67167659,  -5.85296312,  -7.63728214,  -9.32295572,
#        -11.05797704, -12.67760784, -13.89354628, -14.49570921,
#        -14.32954802, -13.21225437, -11.06004387,  -8.14968173,
#         -5.17822842,  -2.96152762,  -2.00480378,  -2.28383159,
#         -3.34516429,  -4.58499502,  -5.53868551,  -6.03316624,
#         -6.12622422,  -5.8587201 ,  -5.04284573,  -3.35468315,
#         -0.72348923,   2.36091908,   4.99347008,   6.38602965,
#          6.31146844,   5.08947584,   3.2190688 ,   1.02062021,
#         -1.46691228,  -4.33882551,  -7.54952633, -10.70298609,
#        -13.10848612, -14.13965784, -13.63950446, -12.03863455,
#        -10.10784995,  -8.56664637,  -7.81076482,  -7.84808565,
#         -8.37062575,  -8.89178991,  -8.9289324 ,  -8.20855692,
#         -6.81230505,  -5.12577047,  -3.55843858,  -2.24863868,
#         -1.02208567,   0.34965674,   1.84159652,   3.12103962,
#          3.79071469,   3.69641174,   3.00910655,   1.97328883,
#          0.53052628,  -1.78055894,  -5.42461014, -10.22598588,
#         -1.79443436,   0.90483026,   2.11539272,   2.10214177,
#          1.35360918,   0.10573586,  -1.76315028,  -4.44721753,
#         -7.82297212, -11.28327275, -13.96433028, -15.26672021,
#        -15.28250246, -14.7145592 , -14.26391437, -14.00370818,
#        -13.36712581, -11.80860947,  -9.50567915,  -7.36351296,
#         -6.27899364,  -6.38731513,  -7.00275409,  -7.19754396,
#         -6.34267405,  -4.1936172 ,  -0.75852073,   3.63600158,
#          8.15618572,  11.55362355,  12.68868713,  11.10164324,
#          7.1878674 ,   1.88748896,  -3.79253947,  -9.0903769 ,
#        -13.52018756, -16.7866333 , -18.78550721, -19.71193142,
#        -20.09140117, -20.59580877, -21.71914668, -23.50635732,
#        -25.47840661, -26.80208229, -26.68396548, -24.84267152,
#        -21.7742915 , -18.54157814, -16.20403376, -15.31352036,
#        -15.81317072, -17.28754596])

# %% [markdown]
# Function where you can give it 2 different files to plot on the same figure.

# %%
# give x as ds, the two indices, and the time array
def plot_two(ds, arr1, arr2, times):
    label1 = ds['flist'][arr1][0][0][0]
    label2 = ds['flist'][arr2][0][0][0]
    trans1 = ds['T'][arr1]
    trans2 = ds['T'][arr2]
    fig, ax = plt.subplots(figsize=(14,8))
    ax.set_ylabel('Transport (Sv)')
    ax.set_xlabel('Time')
    ax.plot(times, trans1, 'b', label=label1)
    ax.plot(times, trans2, 'r', label=label2)
    ax.set_xlim(times[0], times[-1])
    ax.legend()
    ax.grid(True)
    plt.title('Comparing Two Transport Calculations', fontsize=20)
    plt.show()
    print(label1)
    print(label2)

# %%
x['flist']
# Out:
# array([[(array(['SolomonStrait_geoBotRef_linearXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U63'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:31:00'], dtype='<U20'), array([[47652629]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60486111]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_linear2bot_linear2surf.mat'],
#       dtype='<U65'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:08:21'], dtype='<U20'), array([[47647015]], dtype=int32), array([[0]], dtype=uint8), array([[737369.58913194]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_linear2bot_sat4surf.mat'],
#       dtype='<U62'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:23:07'], dtype='<U20'), array([[47653043]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59938657]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_linear2bot_slab2surf.mat'],
#       dtype='<U63'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:15:43'], dtype='<U20'), array([[45932090]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59424769]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U61'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:34:45'], dtype='<U20'), array([[39774364]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60746528]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_slab2bot_linear2surf.mat'],
#       dtype='<U63'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:12:04'], dtype='<U20'), array([[39766690]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59171296]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_slab2bot_sat4surf.mat'],
#       dtype='<U60'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:27:06'], dtype='<U20'), array([[39776982]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60215278]]))],
#        [(array(['SolomonStrait_geoBotRef_linearXsection_slab2bot_slab2surf.mat'],
#       dtype='<U61'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:19:24'], dtype='<U20'), array([[38043465]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59680556]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:32:11'], dtype='<U20'), array([[18238295]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60568287]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_linear2bot_linear2surf.mat'],
#       dtype='<U66'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:09:30'], dtype='<U20'), array([[18237207]], dtype=int32), array([[0]], dtype=uint8), array([[737369.58993056]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_linear2bot_sat4surf.mat'],
#       dtype='<U63'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:24:21'], dtype='<U20'), array([[18237699]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60024306]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_linear2bot_slab2surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:16:50'], dtype='<U20'), array([[17759875]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59502315]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U62'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:35:53'], dtype='<U20'), array([[16044919]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60825231]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_slab2bot_linear2surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:13:10'], dtype='<U20'), array([[16043744]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59247685]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_slab2bot_sat4surf.mat'],
#       dtype='<U61'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:28:21'], dtype='<U20'), array([[16045492]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60302083]]))],
#        [(array(['SolomonStrait_geoBotRef_nearestXsection_slab2bot_slab2surf.mat'],
#       dtype='<U62'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:20:31'], dtype='<U20'), array([[15561987]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59758102]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:33:28'], dtype='<U20'), array([[46005560]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60657407]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_linear2bot_linear2surf.mat'],
#       dtype='<U66'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:10:47'], dtype='<U20'), array([[46002059]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59082176]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_linear2bot_sat4surf.mat'],
#       dtype='<U63'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:25:43'], dtype='<U20'), array([[46006032]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60119213]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_linear2bot_slab2surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:18:06'], dtype='<U20'), array([[44455249]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59590278]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U62'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:37:10'], dtype='<U20'), array([[38148496]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60914352]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_slab2bot_linear2surf.mat'],
#       dtype='<U64'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:14:24'], dtype='<U20'), array([[38143012]], dtype=int32), array([[0]], dtype=uint8), array([[737369.59333333]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_slab2bot_sat4surf.mat'],
#       dtype='<U61'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:29:43'], dtype='<U20'), array([[38151149]], dtype=int32), array([[0]], dtype=uint8), array([[737369.60396991]]))],
#        [(array(['SolomonStrait_geoBotRef_westernXsection_slab2bot_slab2surf.mat'],
#       dtype='<U62'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['05-Nov-2018 14:21:45'], dtype='<U20'), array([[36588622]], dtype=int32), array([[0]], dtype=uint8), array([[737369.5984375]]))],
#        [(array(['SolomonStrait_linearXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U53'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:15:13'], dtype='<U20'), array([[92108554]], dtype=int32), array([[0]], dtype=uint8), array([[737368.01056713]]))],
#        [(array(['SolomonStrait_linearXsection_linear2bot_linear2surf.mat'],
#       dtype='<U55'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:50:12'], dtype='<U20'), array([[92110822]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99319444]]))],
#        [(array(['SolomonStrait_linearXsection_linear2bot_sat4surf.mat'],
#       dtype='<U52'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:06:48'], dtype='<U20'), array([[92109286]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00472222]]))],
#        [(array(['SolomonStrait_linearXsection_linear2bot_slab2surf.mat'],
#       dtype='<U53'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:58:27'], dtype='<U20'), array([[92030631]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99892361]]))],
#        [(array(['SolomonStrait_linearXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U51'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:19:23'], dtype='<U20'), array([[76021592]], dtype=int32), array([[0]], dtype=uint8), array([[737368.01346065]]))],
#        [(array(['SolomonStrait_linearXsection_slab2bot_linear2surf.mat'],
#       dtype='<U53'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:54:06'], dtype='<U20'), array([[76024412]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99590278]]))],
#        [(array(['SolomonStrait_linearXsection_slab2bot_sat4surf.mat'], dtype='<U50'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:10:56'], dtype='<U20'), array([[76021943]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00759259]]))],
#        [(array(['SolomonStrait_linearXsection_slab2bot_slab2surf.mat'],
#       dtype='<U51'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:02:26'], dtype='<U20'), array([[75943332]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00168981]]))],
#        [(array(['SolomonStrait_nearestXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:16:22'], dtype='<U20'), array([[32813207]], dtype=int32), array([[0]], dtype=uint8), array([[737368.01136574]]))],
#        [(array(['SolomonStrait_nearestXsection_linear2bot_linear2surf.mat'],
#       dtype='<U56'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:51:25'], dtype='<U20'), array([[32813352]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99403935]]))],
#        [(array(['SolomonStrait_nearestXsection_linear2bot_sat4surf.mat'],
#       dtype='<U53'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:08:03'], dtype='<U20'), array([[32813430]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00559028]]))],
#        [(array(['SolomonStrait_nearestXsection_linear2bot_slab2surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:59:37'], dtype='<U20'), array([[32661045]], dtype=int32), array([[0]], dtype=uint8), array([[737367.9997338]]))],
#        [(array(['SolomonStrait_nearestXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U52'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:20:40'], dtype='<U20'), array([[28113151]], dtype=int32), array([[0]], dtype=uint8), array([[737368.01435185]]))],
#        [(array(['SolomonStrait_nearestXsection_slab2bot_linear2surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:55:31'], dtype='<U20'), array([[28113922]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99688657]]))],
#        [(array(['SolomonStrait_nearestXsection_slab2bot_sat4surf.mat'],
#       dtype='<U51'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:12:14'], dtype='<U20'), array([[28113426]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00849537]]))],
#        [(array(['SolomonStrait_nearestXsection_slab2bot_slab2surf.mat'],
#       dtype='<U52'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:03:40'], dtype='<U20'), array([[27958187]], dtype=int32), array([[0]], dtype=uint8), array([[737368.0025463]]))],
#        [(array(['SolomonStrait_westernXsection_linear2bot_gcur4surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:17:47'], dtype='<U20'), array([[88813650]], dtype=int32), array([[0]], dtype=uint8), array([[737368.01234954]]))],
#        [(array(['SolomonStrait_westernXsection_linear2bot_linear2surf.mat'],
#       dtype='<U56'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:52:45'], dtype='<U20'), array([[88815045]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99496528]]))],
#        [(array(['SolomonStrait_westernXsection_linear2bot_sat4surf.mat'],
#       dtype='<U53'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:09:26'], dtype='<U20'), array([[88814378]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00655093]]))],
#        [(array(['SolomonStrait_westernXsection_linear2bot_slab2surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:00:58'], dtype='<U20'), array([[88750154]], dtype=int32), array([[0]], dtype=uint8), array([[737368.0006713]]))],
#        [(array(['SolomonStrait_westernXsection_slab2bot_gcur4surf.mat'],
#       dtype='<U52'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:22:07'], dtype='<U20'), array([[72768697]], dtype=int32), array([[0]], dtype=uint8), array([[737368.0153588]]))],
#        [(array(['SolomonStrait_westernXsection_slab2bot_linear2surf.mat'],
#       dtype='<U54'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['03-Nov-2018 23:56:54'], dtype='<U20'), array([[72770886]], dtype=int32), array([[0]], dtype=uint8), array([[737367.99784722]]))],
#        [(array(['SolomonStrait_westernXsection_slab2bot_sat4surf.mat'],
#       dtype='<U51'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:13:44'], dtype='<U20'), array([[72768971]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00953704]]))],
#        [(array(['SolomonStrait_westernXsection_slab2bot_slab2surf.mat'],
#       dtype='<U52'), array(['/Users/marionsofiaalberty/MATLAB/Solomon_Sea/Moorings/Data/Gridded/SolomonStrait'],
#       dtype='<U80'), array(['04-Nov-2018 00:05:11'], dtype='<U20'), array([[72704671]], dtype=int32), array([[0]], dtype=uint8), array([[737368.00359954]]))]],
#       dtype=[('name', 'O'), ('folder', 'O'), ('date', 'O'), ('bytes', 'O'), ('isdir', 'O'), ('datenum', 'O')])

# %%
plot_two(x, 28, 29, py_dt)
# Out:
# SolomonStrait_linearXsection_slab2bot_gcur4surf.mat
# SolomonStrait_linearXsection_slab2bot_linear2surf.mat

# %%
plot_two(x, 4, 5, py_dt)
# Out:
# SolomonStrait_geoBotRef_linearXsection_slab2bot_gcur4surf.mat
# SolomonStrait_geoBotRef_linearXsection_slab2bot_linear2surf.mat

# %% [markdown]
# ## 4. Plot three files to compare

# %%
def plot_tres(ds, arr1, arr2, arr3, times):
    label1 = ds['flist'][arr1][0][0][0]
    label2 = ds['flist'][arr2][0][0][0]
    label3 = ds['flist'][arr3][0][0][0]
    trans1 = ds['T'][arr1]
    trans2 = ds['T'][arr2]
    trans3 = ds['T'][arr3]
    fig, ax = plt.subplots(figsize=(14,8))
    ax.set_ylabel('Transport (Sv)')
    ax.set_xlabel('Time')
    ax.plot(times, trans1, 'b', label=label1)
    ax.plot(times, trans2, 'r', label=label2)
    ax.plot(times, trans3, 'g', label=label3)
    ax.set_xlim(times[0], times[-1])
    ax.legend()
    ax.grid(True)
    plt.title('Comparing Three Transport Calculations', fontsize=20)
    plt.show()
    print(label1)
    print(label2)
    print(label3)

# %%
plot_tres(x, 0,16,20, py_dt)
# Out:
# SolomonStrait_geoBotRef_linearXsection_linear2bot_gcur4surf.mat
# SolomonStrait_geoBotRef_westernXsection_linear2bot_gcur4surf.mat
# SolomonStrait_geoBotRef_westernXsection_slab2bot_gcur4surf.mat

# %% [markdown]
# ## 5. Plot four together to compare

# %%
def plot_four(ds, arr1, arr2, arr3, arr4, times):
    label1 = ds['flist'][arr1][0][0][0]
    label2 = ds['flist'][arr2][0][0][0]
    label3 = ds['flist'][arr3][0][0][0]
    label4 = ds['flist'][arr4][0][0][0]
    trans1 = ds['T'][arr1]
    trans2 = ds['T'][arr2]
    trans3 = ds['T'][arr3]
    trans4 = ds['T'][arr4]
    fig, ax = plt.subplots(figsize=(14,8))
    ax.set_ylabel('Transport (Sv)')
    ax.set_xlabel('Time')
    ax.plot(times, trans1, 'b', label=label1)
    ax.plot(times, trans2, 'r', label=label2)
    ax.plot(times, trans3, 'g--', label=label3)
    ax.plot(times, trans4, 'y--', label=label4)
    ax.set_xlim(times[0], times[-1])
    ax.legend()
    ax.grid(True)
    plt.title('Comparing Four Transport Calculations', fontsize=20)
    plt.show()
    print(label1)
    print(label2)
    print(label3)
    print(label4)

# %%
plot_four(x, 4,5,28,29, py_dt)
# Out:
# SolomonStrait_geoBotRef_linearXsection_slab2bot_gcur4surf.mat
# SolomonStrait_geoBotRef_linearXsection_slab2bot_linear2surf.mat
# SolomonStrait_linearXsection_slab2bot_gcur4surf.mat
# SolomonStrait_linearXsection_slab2bot_linear2surf.mat

# %%
plot_four(x,24,25,27,26, py_dt)
# Out:
# SolomonStrait_linearXsection_linear2bot_gcur4surf.mat
# SolomonStrait_linearXsection_linear2bot_linear2surf.mat
# SolomonStrait_linearXsection_linear2bot_slab2surf.mat
# SolomonStrait_linearXsection_linear2bot_sat4surf.mat
