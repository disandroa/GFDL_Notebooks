# %% [markdown]
# # Time Series Comparison of Transport in 100 m to 850 m Range
# *Akira Di Sandro, 7/27/20*
# <br> In this notebook, I will be plotting a time series of the transport comparison between model and observational data of the 100-850 m range of depth where the observational data will be limited to July 2012 - March 2014, but the model data will be plotted from 1984-2014 (30 years).

# %% [markdown]
# ## 1. Import Packages as usual

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import xarray as xr
xr.set_options(display_style='html')
import intake
# %matplotlib inline
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import sectionate

# %% [markdown]
# ## 2. Open Dataset & Load in 'ocean_static.nc'

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(cat_url)

# %%
dog = col.search(source_id='GFDL-CM4', experiment_id='historical', variable_id=['uo','vo'], grid_label='gn')
dog.df
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0        CMIP      NOAA-GFDL  GFDL-CM4    historical  r1i1p1f1     Omon
# 1        CMIP      NOAA-GFDL  GFDL-CM4    historical  r1i1p1f1     Omon
#
#   variable_id grid_label                                             zstore  \
# 0          uo         gn  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...
# 1          vo         gn  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...
#
#    dcpp_init_year   version
# 0             NaN  20180701
# 1             NaN  20180701

# %%
dset_dict = dog.to_dataset_dict(zarr_kwargs={'consolidated': True})
list(dset_dict.keys())
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# ['CMIP.NOAA-GFDL.GFDL-CM4.historical.Omon.gn']

# %%
grid = dset_dict['CMIP.NOAA-GFDL.GFDL-CM4.historical.Omon.gn']
grid
# Out:
# <xarray.Dataset>
# Dimensions:    (bnds: 2, lev: 35, member_id: 1, time: 1980, x: 1440, y: 1080)
# Coordinates:
#     lev_bnds   (lev, bnds) float64 dask.array<chunksize=(35, 2), meta=np.ndarray>
#     time_bnds  (time, bnds) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#     lon        (y, x) float32 dask.array<chunksize=(1080, 1440), meta=np.ndarray>
#     lat        (y, x) float32 dask.array<chunksize=(1080, 1440), meta=np.ndarray>
#   * x          (x) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * lev        (lev) float64 2.5 10.0 20.0 32.5 ... 5e+03 5.5e+03 6e+03 6.5e+03
#   * time       (time) object 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#   * y          (y) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * bnds       (bnds) float64 1.0 2.0
#   * member_id  (member_id) <U8 'r1i1p1f1'
# Data variables:
#     uo         (member_id, time, lev, y, x) float32 dask.array<chunksize=(1, 1, 35, 1080, 1440), meta=np.ndarray>
#     vo         (member_id, time, lev, y, x) float32 dask.array<chunksize=(1, 1, 35, 1080, 1440), meta=np.ndarray>
# Attributes:
#     comment:                 <null ref>
#     institution:             National Oceanic and Atmospheric Administration,...
#     sub_experiment:          none
#     realm:                   ocean
#     source:                  GFDL-CM4 (2018): \naerosol: interactive\natmos: ...
#     license:                 CMIP6 model data produced by NOAA-GFDL is licens...
#     initialization_index:    1
#     nominal_resolution:      25 km
#     experiment:              historical
#     parent_activity_id:      CMIP
#     further_info_url:        https://furtherinfo.es-doc.org/CMIP6.NOAA-GFDL.G...
#     realization_index:       1
#     branch_method:           standard
#     references:              see further_info_url attribute
#     institution_id:          NOAA-GFDL
#     product:                 model-output
#     tracking_id:             hdl:21.14100/d0ebcd36-d2cd-442e-a8d9-8f7a27168a2...
#     variant_info:            N/A
#     mip_era:                 CMIP6
#     sub_experiment_id:       none
#     frequency:               mon
#     history:                 File was processed by fremetar (GFDL analog of C...
#     title:                   NOAA GFDL GFDL-CM4 model output prepared for CMI...
#     parent_mip_era:          CMIP6
#     parent_variant_label:    r1i1p1f1
#     variant_label:           r1i1p1f1
#     parent_time_units:       days since 0001-1-1
#     experiment_id:           historical
#     source_type:             AOGCM
#     contact:                 gfdl.climate.model.info@noaa.gov
#     parent_source_id:        GFDL-CM4
#     grid_label:              gn
#     branch_time_in_child:    0.0
#     forcing_index:           1
#     activity_id:             CMIP
#     branch_time_in_parent:   36500.0
#     Conventions:             CF-1.7 CMIP-6.0 UGRID-1.0
#     physics_index:           1
#     parent_experiment_id:    piControl
#     grid:                    ocean data on native grid tripolar - nominal 0.2...
#     table_id:                Omon
#     data_specs_version:      01.00.27
#     status:                  2019-08-06;created;by nhn2@columbia.edu
#     source_id:               GFDL-CM4
#     intake_esm_dataset_key:  CMIP.NOAA-GFDL.GFDL-CM4.historical.Omon.gn

# %%
o_s = xr.open_dataset('Data Files/ocean_static.nc')
o_s
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 1, xh: 1440, xq: 1440, yh: 1080, yq: 1080)
# Coordinates:
#   * xh            (xh) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * yh            (yh) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * time          (time) object 1900-01-01 00:00:00
#   * xq            (xq) float64 -299.6 -299.3 -299.1 -298.9 ... 59.66 59.91 60.16
#   * yq            (yq) float64 -80.35 -80.27 -80.19 -80.11 ... 89.78 89.89 90.0
# Data variables:
#     areacello     (yh, xh) float32 ...
#     deptho        (yh, xh) float32 ...
#     hfgeou        (yh, xh) float32 ...
#     sftof         (yh, xh) float32 ...
#     Coriolis      (yq, xq) float32 ...
#     geolon        (yh, xh) float32 ...
#     geolat        (yh, xh) float32 ...
#     geolon_c      (yq, xq) float32 ...
#     geolat_c      (yq, xq) float32 ...
#     geolon_u      (yh, xq) float32 ...
#     geolat_u      (yh, xq) float32 ...
#     geolon_v      (yq, xh) float32 ...
#     geolat_v      (yq, xh) float32 ...
#     wet           (yh, xh) float32 ...
#     wet_c         (yq, xq) float32 ...
#     wet_u         (yh, xq) float32 ...
#     wet_v         (yq, xh) float32 ...
#     dxt           (yh, xh) float32 ...
#     dyt           (yh, xh) float32 ...
#     dxCu          (yh, xq) float32 ...
#     dyCu          (yh, xq) float32 ...
#     dxCv          (yq, xh) float32 ...
#     dyCv          (yq, xh) float32 ...
#     areacello_cu  (yh, xq) float32 ...
#     areacello_cv  (yq, xh) float32 ...
#     areacello_bu  (yq, xq) float32 ...
#     basin         (yh, xh) int32 ...
# Attributes:
#     filename:   19000101.ocean_static.nc
#     title:      OM4_SIS2_cgrid_025
#     grid_type:  regular
#     grid_tile:  N/A

# %%
dxCv = o_s['dxCv']
dyCu = o_s['dyCu']
geolon_u = o_s['geolon_u']
geolat_u = o_s['geolat_u']
geolon_v = o_s['geolon_v']
geolat_v = o_s['geolat_v']

# %% [markdown]
# ### Opening Observational Data

# %%
from scipy.io import loadmat
obs_data = loadmat('../Data/SolomonStrait_westernXsection_linear2bot_sat4surf.mat')

# %%
#along strait velocity saved in 255x99x590 matrix (depth x points along cross section x timestamps)
asv = obs_data['ASV']  #asv is in m/s
asv[np.isnan(asv)] = 0  #getting rid of all the nan's in asv, making them zero

#lon: lon points along cross section, lat (same as lon), xdist: distance from start of cross section
lon = obs_data['bathy'][0][0][2][0]
lat = obs_data['bathy'][0][0][3][0]
xdist = obs_data['bathy'][0][0][4][0] #xdist is in km
xdist = xdist*10**3   #xdist is now in m

#raw_time: datenums associated to each day mooring data was taken
rawobstime = obs_data['time'][0]

#depth: array of all the depths possible
depth = obs_data['z'][:,0]  # depth is in m

# %% [markdown]
# Here, I have to first convert the datenums that are legible in matlab to a datetime formate that python understands.

# %%
def matlab2datetime(matlab_datenum):
    day = dt.datetime.fromordinal(int(matlab_datenum))
    dayfrac = dt.timedelta(days=matlab_datenum%1) - dt.timedelta(days = 366)
    return day + dayfrac

# %%
obstime = []

for time in rawobstime:
    obstime = np.concatenate([obstime, [matlab2datetime(int(time))]])

# %% [markdown]
# ### Calculating Observational Monthly Transport Averages

# %% [markdown]
# First, I have to make a function where I can give it a certain depth range, and it will give me the observational data transport over the time I'm interested in for that depth range (so the output should be a 1d array).
# <br>
# <br> In this function, I will give it the along strait velocities, starting depth and ending depth that I want, along with the xdist in order to do the horizontal trapezoidal integration.

# %% [markdown]
# I first consructed an array that stores the 12 months I'm interested in to create monthly averages of the transport data stored in the observational data.

# %%
mon_times = []   #21 months total
for i in range(2012,2015):
    for j in range(1,13):
        if i == 2012 and j < 7:
            pass
        elif i == 2014 and j > 3:
            pass
        else:
            mon_times = np.append(mon_times, dt.datetime(i,j,1))

# %% [markdown]
# Next, I am storing the indices of the times from the observational data that match with the start date as well as the first of each month so that I can then average all the trasnport values for each day in each month I'm interested in.

# %%
indices = []
for i in range(len(obstime)):
    if obstime[i] == dt.datetime(2012,7,23):
        indices = np.append(indices, i)
    for j in range(2012,2015):
        for k in range(1,13):
            if obstime[i] == dt.datetime(j,k,1):
                indices = np.append(indices, i)

# %% [markdown]
# Now, I'm making a function to calculate the monthly transport values for specific depth ranges I'm interested in. I specify the depths I'm interested in, average the ASV values across the months, integrate trapezoidally across the points along the cross section, multiply by 20 (because each grid cell is 20 m deep), sum along the depth dimension, and lastly change the units to Sverdrups.

# %%
def calc_obs_trans(asv,start_dp,end_dp,depth,xdist,indices):
    # first figure out chunk of depths I'm interested in
    dp = np.where((depth >= start_dp) & (depth <= end_dp))
    asv_dp = asv[dp]
    
    # average the asv values over months
    asv_mon = np.zeros((dp[0].shape[0],asv.shape[1],indices.shape[0]))        # asv_mon is where i will store the monthly averaged asv's
    for i in range(len(indices)):
        ind = int(indices[i])
        if ind == 586:
            mon_mean = asv_dp[:,:,586:].mean(axis=2)
            asv_mon[:,:,i] = mon_mean
        else:
            ind2 = int(indices[i+1])
            mon_mean = asv_dp[:,:,ind:ind2].mean(axis=2)
            asv_mon[:,:,i] = mon_mean
    
    # do a trapezoidal integration along the strait for each month
    asv_trapz = np.zeros((dp[0].shape[0],indices.shape[0]))
    for i in range(dp[0].shape[0]):
        for j in range(indices.shape[0]):
            temp = asv_mon[i,:,j]
            temptrapz = np.trapz(temp, xdist)
            asv_trapz[i,j] = temptrapz
    
    # multiply the whole matrix by 20 for the depth of each cell & sum along the depth dimension
    transport = asv_trapz.sum(axis=0)*20/10**6
    
    return(transport)

# %%
obs_transport = calc_obs_trans(asv,100,850,depth,xdist,indices)
obs_transport
# Out:
# array([19.41116318, 17.4903831 , 16.35700902, 16.53525756, 18.21008781,
#        18.45871851, 14.59991744, 10.40867032, -0.5115661 ,  3.64968376,
#         5.61508101, 14.55430783, 15.88662382, 10.37719876, 14.24972057,
#        18.52708591, 13.5155185 , 12.8922628 ,  9.81981966,  6.69036966,
#         8.90323197])

# %% [markdown]
# ## 3. Open Cluster

# %%
from dask.distributed import Client
from dask_gateway import Gateway


gateway = Gateway()  # connect to Gateway

cluster = gateway.new_cluster()  # create cluster
cluster.scale(10)  # scale cluster

client = Client(cluster)  # connect Client to Cluster

# %%
client
# Out:
# <Client: 'tls://10.37.154.15:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## 4. UVdata Calculations

# %% [markdown]
# The following are the lat and lon from the observational data. I had to adjust the values so that they are in similar places and are still on land for the model data.
# <br> (-4.78819598936245, 152.903)
# <br> (-5.137642131304778, 154.555)

# %%
lat1 = -4.78819598936245
lon1 = -208.21236
lat2 = -5.989064
lon2 = -205.234668

# %%
#isec, jsec, xsec, ysec = sectionate.create_section(grid['lon'], grid['lat'], lon1, lat1, lon2, lat2)

# %%
isec = np.array([367, 368, 369, 369, 370, 371, 372, 372, 373, 374, 374, 375, 376,
       377, 377, 378])

# %%
jsec = np.array([483, 483, 483, 482, 482, 482, 482, 481, 481, 481, 480, 480, 480,
       480, 479, 479])

# %%
uvpoints = sectionate.transports_C.MOM6_UVpoints_from_section(isec, jsec)
data = np.empty((len(uvpoints),5))
count = 0

for i in range(len(uvpoints)):
    point = uvpoints[i]
    pttype, i, j = point
    i = int(i)
    j = int(j)
    if pttype == 'U':
        lon = geolon_u.isel(xq=i, yh=j).values
        lat = geolat_u.isel(xq=i, yh=j).values
        data[count] = [0, i, j, lon, lat]  
        count += 1
    else:
        lon = geolon_v.isel(xh=i, yq=j).values
        lat = geolat_v.isel(xh=i, yq=j).values
        data[count] = [1, i, j, lon, lat]  
        count += 1
# print(f'{point[0]}, {point[1]}, {point[2]}, {lon}, {lat}')

# %% [markdown]
# ## 5. Surface Area Calculations
# I want to use the udata and vdata to the use the corresponding 'x' and 'y' points to save the side lengths into a vector. I then need to use those side lengths and multiply by the thickness of each cell (which I calculate using my 'find_dz' function) to get the surface areas for each grid cell in the cross section that I'm interested in. Once I have this information, I can calculate transport the way I wanted to before.

# %% [markdown]
# Make vector 'dsides' that stores the different lengths from i,j-point to i,j-point to then multiply by depths to get SA values.

# %%
dsides = []
for d in data:
    dtype,i,j,lon,lat = d
    i = int(i)
    j = int(j)
    if dtype == 0:
        dy = dyCu.isel(xq=i,yh=j).values
        dsides = np.append(dsides, dy)
    else:
        dx = dxCv.isel(xh=i,yq=j).values
        dsides = np.append(dsides, dx)

# %% [markdown]
# Now, I need to calculate the depth variables for each point.

# %%
deepest = []
for d in data:
    dtype,i,j,_,_ = d
    i,j = int(i),int(j)
    depth = o_s['deptho'].isel(xh=i,yh=j).values
    deepest = np.append(deepest,depth)

# %% [markdown]
# With 'deepest', I am finding the deepest measurement I can count as the ocean floor for each point in 'data'. This will help me in my function to find the right SA values.

# %%
lev = grid['lev']

# %% [markdown]
# Since 'lev' contains values of the midpoints of the grid cells, I need the function 'find_dz' to tell me how deep each grid cell is.

# %%
def find_dz(lev):
    mylev = []
    depth = 0
    for i in range(len(lev)):
        dz = abs(depth-lev[i])*2
        depth += dz
        mylev = np.append(mylev,dz)
    return mylev

# %% [markdown]
# The function 'find_dz' finds the dz/dr, or the depth of each grid cell.

# %%
mylev = find_dz(lev[:30])

# %% [markdown]
# I want to make an array (call it 'zl') that stores the values of the edges of the grid boxes in the vertical direction.

# %%
zl = np.array([0])
dpth = 0
for i in mylev:
    dpth += i
    zl = np.append(zl, dpth)

# %% [markdown]
# I want to make a (point x depth) array now that stores in all the 'dz' that correspond to each point in the cross section.

# %%
SA = np.empty((dsides.shape[0], mylev.shape[0]))

# %% [markdown]
# I modified the original function to allow me to choose what depth level to stop at. The elif statement allows me to select a fraction of the last grid cell that partially has water in it so that I can get a better estimate of the total transport.

# %%
#still have to modify to reflect 
def calc_SA_specificdepth(SA,dsides,mylev,lev,deepest,shallowest):
    for i in range(len(dsides)):
        for j in range(len(mylev)):
            if shallowest < lev[j] < deepest:
                SA[i][j] = dsides[i] * mylev[j]
            elif shallowest < lev[j-1] < deepest and lev[j] > deepest:
                dif = deepest - lev[j-1].values
                SA[i][j] = dsides[i] * dif
            else:
                SA[i][j] = 0
    return SA

# %%
SA850 = calc_SA_specificdepth(SA,dsides,mylev,lev,850,100)

# %% [markdown]
# In order to not make a 3d vel_mat matrix of 30 depth points, I will use 'dp_value' that stores the amount of non-zero elements the SA_mat has for each depth range I'm interested in.

# %%
start_ind = np.nonzero(SA850[0])[0][0]
end_ind = np.nonzero(SA850[0])[0][-1]
start_ind,end_ind
# Out:
# (7, 17)

# %%
dp_value = np.nonzero(SA850[0])[0].shape[0]

# %% [markdown]
# ## 6. Calculating Transport from this SA data

# %% [markdown]
# I changed the transport calculation function once again to have a 3d matrix of velocity indexed by points along the cross section, time, and depth points. This takes about a minute to make. After I make this matrix, I can then do calculations much more easily and quickly.

# %%
def make_velmat(ds,data,start,end,dp,times):
    vel_mat = np.zeros((data.shape[0],times.shape[0],dp))
    for d in range(len(data)):
        dtype,i,j,lon,lat = data[d]
        i,j=int(i),int(j)
        if dtype == 0:
            vel_mat[d] = ds['uo'].isel(member_id=0,x=i,y=j,time=slice(times[0],times[-1]+1),lev=slice(start,end+1))
        else:
            vel_mat[d] = ds['vo'].isel(member_id=0,x=i,y=j,time=slice(times[0],times[-1]+1),lev=slice(start,end+1))
    return vel_mat

# %% [markdown]
# 'times' is an array that stores the time indices I'm interested in that I can use to plug into the transport calculation function while 'times1' is the array I will use to actually plot the transport values.

# %%
times = np.arange(1611,1971)
times.shape
# Out:
# (360,)

# %%
vel_mat3d = make_velmat(grid, data, start_ind,end_ind,dp_value,times)

# %%
trans_mat3d = np.zeros((vel_mat3d.shape[0],vel_mat3d.shape[1],vel_mat3d.shape[2]))
for i in range(vel_mat3d.shape[1]):
    trans_mat3d[:,i] = SA850[:,start_ind:end_ind+1] * vel_mat3d[:,i]
trans_mat3d[np.isnan(trans_mat3d)] = 0

# %%
transport = np.zeros(times.shape[0])
for i in range(trans_mat3d.shape[1]):
    transport[i] = trans_mat3d[:,i].sum()

# %%
trans_sv = transport*10**-6
trans_sv.shape
# Out:
# (360,)

# %%
times1 = grid['time'][1950:1971]
times2 = grid['time'][1611:1971]

# %% [markdown]
# ## 7. Plotting Transport

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.set_ylabel('Transport (Sv)')
ax.set_xlabel('Time')
label1 = 'Monthly Average of Observational Transport'
label2 = 'Monthly Average of Model Transport'
ax.plot(times1, obs_transport, 'b', label=label1)
ax.plot(times2, trans_sv, 'r', label=label2)
ax.set_xlim(times2.values[0], times2.values[-1])
ax.grid(True)
ax.legend()
plt.title('Monthly Time series of Observational and Model Transport of Depth Range: 100-850m from 1984-2014', fontsize=20)
model_trans_plot = plt.show()

# %% [markdown]
# ## 8. Writing Data into CSV File

# %%
import csv

# %%
with open('mtrans100-850.csv', 'w', newline='') as f:
    fieldnames = ['time indices','times','model transport','observational transport']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    
    writer.writeheader()
    for i in range(len(times2)):
        if 360-i <= 21:
            writer.writerow({'time indices' : times[i], 'times' : times2[i], 'model transport' : trans_sv[i], 'observational transport' : obs_transport[i-339]})
        else:
            writer.writerow({'time indices' : times[i], 'times' : times2[i], 'model transport' : trans_sv[i]})

# %%
with open('mtrans0-100.csv', 'r', newline='') as f:
    reader = csv.reader(f)

# %% [markdown]
# ## Closing Clusters after use

# %%
client.close()
cluster.close()
